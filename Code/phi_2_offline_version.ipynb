# %% [markdown]
# <a href="https://colab.research.google.com/github/cobusgreyling/hugging-face/blob/main/phi_2_offline_version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install git+https://github.com/huggingface/transformers
# Out:
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to /private/var/folders/6d/6svky4ks0bj_py5wk86hz5k40000gn/T/pip-req-build-lqw8p136
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /private/var/folders/6d/6svky4ks0bj_py5wk86hz5k40000gn/T/pip-req-build-lqw8p136
#   Resolved https://github.com/huggingface/transformers to commit f745e7d3f902601686b83c7cce2660c2a94509f0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from transformers==4.45.0.dev0) (3.16.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from transformers==4.45.0.dev0) (0.24.6)
# Requirement already satisfied: numpy>=1.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from transformers==4.45.0.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from transformers==4.45.0.dev0) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from transformers==4.45.0.dev0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from transformers==4.45.0.dev0) (2024.7.24)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from transformers==4.45.0.dev0) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from transformers==4.45.0.dev0) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from transformers==4.45.0.dev0) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from transformers==4.45.0.dev0) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.45.0.dev0) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.45.0.dev0) (4.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->transformers==4.45.0.dev0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->transformers==4.45.0.dev0) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->transformers==4.45.0.dev0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->transformers==4.45.0.dev0) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install sentencepiece accelerate einops
# Out:
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting accelerate
#   Downloading accelerate-0.34.2-py3-none-any.whl.metadata (19 kB)
# Collecting einops
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from accelerate) (5.9.8)
# Requirement already satisfied: pyyaml in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from accelerate) (6.0.1)
# Collecting torch>=1.10.0 (from accelerate)
#   Downloading torch-2.4.1-cp311-none-macosx_11_0_arm64.whl.metadata (26 kB)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from accelerate) (0.24.6)
# Requirement already satisfied: safetensors>=0.4.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from accelerate) (0.4.5)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate) (3.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate) (2024.9.0)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.1)
# Collecting sympy (from torch>=1.10.0->accelerate)
#   Downloading sympy-1.13.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2024.8.30)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch>=1.10.0->accelerate)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading sentencepiece-0.2.0-cp311-cp311-macosx_11_0_arm64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.9 MB/s eta 0:00:00
# Downloading accelerate-0.34.2-py3-none-any.whl (324 kB)
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
# Downloading torch-2.4.1-cp311-none-macosx_11_0_arm64.whl (62.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 MB 29.0 MB/s eta 0:00:0000:0100:01
# Downloading sympy-1.13.2-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 27.3 MB/s eta 0:00:00a 0:00:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 18.2 MB/s eta 0:00:00
# Installing collected packages: sentencepiece, mpmath, sympy, einops, torch, accelerate
# Successfully installed accelerate-0.34.2 einops-0.8.0 mpmath-1.3.0 sentencepiece-0.2.0 sympy-1.13.2 torch-2.4.1

# %%
import torch

# %%
x = torch.rand(5, 3)
print(x)
torch.cuda.is_available()
# Out:
# tensor([[0.6143, 0.9326, 0.1963],
#         [0.9102, 0.0308, 0.5327],
#         [0.5640, 0.3481, 0.4785],
#         [0.3779, 0.2651, 0.4443],
#         [0.7524, 0.4165, 0.8198]])
# False

# %%
from huggingface_hub import snapshot_download

# %%
repo_id = 'microsoft/phi-2'

model_path = snapshot_download(repo_id=repo_id,repo_type="model", local_dir="./phi-2", local_dir_use_symlinks=False)

model_path = "./phi-2"
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/huggingface_hub/file_download.py:1212: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 17 files:   0%|          | 0/17 [00:00<?, ?it/s]
# LICENSE:   0%|          | 0.00/1.08k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/7.80k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/735 [00:00<?, ?B/s]
# SECURITY.md:   0%|          | 0.00/2.66k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# CODE_OF_CONDUCT.md:   0%|          | 0.00/444 [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/1.08k [00:00<?, ?B/s]
# NOTICE.md:   0%|          | 0.00/1.77k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/35.7k [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.34k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/564M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]

# %%
tokenizer = AutoTokenizer.from_pretrained(model_path, trust_remote_code=True)

# Needs 12GB of vRAM to run in float32 (default)
# Run this line to load in float16. You need Gb of vRAM
torch.set_default_dtype(torch.float16)

model = AutoModelForCausalLM.from_pretrained(model_path, device_map="auto", trust_remote_code=True)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Some parameters are on the meta device because they were offloaded to the disk.

# %%
model.device
# Out:
# device(type='mps', index=0)

# %%
import time
def generate(prompt: str, generation_params: dict = {"max_length":200})-> str :
    s = time.time()

    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
    outputs = model.generate(**inputs, **generation_params)
    completion = tokenizer.batch_decode(outputs)[0]

    elapsed = time.time() - s

    num_input_tokens = inputs['input_ids'].shape[1]
    num_total_tokens = outputs.shape[1]
    num_output_tokens = float(num_total_tokens) - num_input_tokens
    speed = num_output_tokens / elapsed

    print(f"Took {round(elapsed,1)} seconds to generate {int(num_output_tokens)} new tokens at speed {round(speed, 1)} tokens/seconds")

    return completion

# %%
prompt = """
Create a list of 5 words which have a similar meating to the word hope.

"""

# %%
result = generate(prompt, generation_params={"max_length":200})
result
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 result = generate(prompt, generation_params={"max_length":200})
#       2 result
#
# Cell In[10], line 5, in generate(prompt, generation_params)
#       2 def generate(prompt: str, generation_params: dict = {"max_length":200})-> str :
#       3     s = time.time()
# ----> 5     inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
#       6     outputs = model.generate(**inputs, **generation_params)
#       7     completion = tokenizer.batch_decode(outputs)[0]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:816, in BatchEncoding.to(self, device)
#     812 # This check catches things like APEX blindly calling "to" on all inputs to a module
#     813 # Otherwise it passes the casts down and casts the LongTensor containing the token idxs
#     814 # into a HalfTensor
#     815 if isinstance(device, str) or is_torch_device(device) or isinstance(device, int):
# --> 816     self.data = {k: v.to(device=device) for k, v in self.data.items() if v is not None}
#     817 else:
#     818     logger.warning(f"Attempting to cast a BatchEncoding to type {str(device)}. This is not supported.")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:816, in <dictcomp>(.0)
#     812 # This check catches things like APEX blindly calling "to" on all inputs to a module
#     813 # Otherwise it passes the casts down and casts the LongTensor containing the token idxs
#     814 # into a HalfTensor
#     815 if isinstance(device, str) or is_torch_device(device) or isinstance(device, int):
# --> 816     self.data = {k: v.to(device=device) for k, v in self.data.items() if v is not None}
#     817 else:
#     818     logger.warning(f"Attempting to cast a BatchEncoding to type {str(device)}. This is not supported.")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/cuda/__init__.py:305, in _lazy_init()
#     300     raise RuntimeError(
#     301         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     302         "multiprocessing, you must use the 'spawn' start method"
#     303     )
#     304 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 305     raise AssertionError("Torch not compiled with CUDA enabled")
#     306 if _cudart is None:
#     307     raise AssertionError(
#     308         "libcudart functions unavailable. It looks like you have a broken build?"
#     309     )
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
result = generate(prompt, generation_params={"max_length":200})
result
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 result = generate(prompt, generation_params={"max_length":200})
#       2 result
#
# Cell In[10], line 5, in generate(prompt, generation_params)
#       2 def generate(prompt: str, generation_params: dict = {"max_length":200})-> str :
#       3     s = time.time()
# ----> 5     inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
#       6     outputs = model.generate(**inputs, **generation_params)
#       7     completion = tokenizer.batch_decode(outputs)[0]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:816, in BatchEncoding.to(self, device)
#     812 # This check catches things like APEX blindly calling "to" on all inputs to a module
#     813 # Otherwise it passes the casts down and casts the LongTensor containing the token idxs
#     814 # into a HalfTensor
#     815 if isinstance(device, str) or is_torch_device(device) or isinstance(device, int):
# --> 816     self.data = {k: v.to(device=device) for k, v in self.data.items() if v is not None}
#     817 else:
#     818     logger.warning(f"Attempting to cast a BatchEncoding to type {str(device)}. This is not supported.")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:816, in <dictcomp>(.0)
#     812 # This check catches things like APEX blindly calling "to" on all inputs to a module
#     813 # Otherwise it passes the casts down and casts the LongTensor containing the token idxs
#     814 # into a HalfTensor
#     815 if isinstance(device, str) or is_torch_device(device) or isinstance(device, int):
# --> 816     self.data = {k: v.to(device=device) for k, v in self.data.items() if v is not None}
#     817 else:
#     818     logger.warning(f"Attempting to cast a BatchEncoding to type {str(device)}. This is not supported.")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/cuda/__init__.py:305, in _lazy_init()
#     300     raise RuntimeError(
#     301         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     302         "multiprocessing, you must use the 'spawn' start method"
#     303     )
#     304 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 305     raise AssertionError("Torch not compiled with CUDA enabled")
#     306 if _cudart is None:
#     307     raise AssertionError(
#     308         "libcudart functions unavailable. It looks like you have a broken build?"
#     309     )
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
result = generate(prompt, generation_params={"max_length":2000})
result
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 result = generate(prompt, generation_params={"max_length":2000})
#       2 result
#
# Cell In[10], line 5, in generate(prompt, generation_params)
#       2 def generate(prompt: str, generation_params: dict = {"max_length":200})-> str :
#       3     s = time.time()
# ----> 5     inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
#       6     outputs = model.generate(**inputs, **generation_params)
#       7     completion = tokenizer.batch_decode(outputs)[0]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:816, in BatchEncoding.to(self, device)
#     812 # This check catches things like APEX blindly calling "to" on all inputs to a module
#     813 # Otherwise it passes the casts down and casts the LongTensor containing the token idxs
#     814 # into a HalfTensor
#     815 if isinstance(device, str) or is_torch_device(device) or isinstance(device, int):
# --> 816     self.data = {k: v.to(device=device) for k, v in self.data.items() if v is not None}
#     817 else:
#     818     logger.warning(f"Attempting to cast a BatchEncoding to type {str(device)}. This is not supported.")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:816, in <dictcomp>(.0)
#     812 # This check catches things like APEX blindly calling "to" on all inputs to a module
#     813 # Otherwise it passes the casts down and casts the LongTensor containing the token idxs
#     814 # into a HalfTensor
#     815 if isinstance(device, str) or is_torch_device(device) or isinstance(device, int):
# --> 816     self.data = {k: v.to(device=device) for k, v in self.data.items() if v is not None}
#     817 else:
#     818     logger.warning(f"Attempting to cast a BatchEncoding to type {str(device)}. This is not supported.")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/cuda/__init__.py:305, in _lazy_init()
#     300     raise RuntimeError(
#     301         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     302         "multiprocessing, you must use the 'spawn' start method"
#     303     )
#     304 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 305     raise AssertionError("Torch not compiled with CUDA enabled")
#     306 if _cudart is None:
#     307     raise AssertionError(
#     308         "libcudart functions unavailable. It looks like you have a broken build?"
#     309     )
#
# AssertionError: Torch not compiled with CUDA enabled
