# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('IndianFoodDataset3.csv',index_col=None)

# %%
#df = df.drop(['Unnamed: 0',	'Unnamed: 0.1',	'Unnamed: 0.1.1'],axis = 1)
df = df.drop(['Unnamed: 0',	'Unnamed: 0.1'],axis = 1)

# %%
df
# Out:
#      Unnamed: 0.2             RecipeName  \
# 0               0                Hù Tiéu
# 1               1                Hù Tiéu
# 2               2               Donzelle
# 3               3           Albaloo Polo
# 4               4  Batatinha em Conserva
# ..            ...                    ...
# 133           133                Pastina
# 134           134       Kakadiche Dhirde
# 135           135        Espagueti Verde
# 136           136                Gombotz
# 137           137    Pink Beetroot Pasta
#
#                                            Ingredients           Course  \
# 0    ['dry rice noodles medium size', 'Hù Tiéu soup...        Breakfast
# 1    ['dry rice noodles medium size', 'Hù Tiéu soup...        Breakfast
# 2    ['500 g 00 flour', '1 Tbsp sugar', '1 Tbsp sal...            Snack
# 3    ['2 cups Basmati Rice', '2 tbsp Salt', '1/8 ts...           Dinner
# 4    ['1 can cooked baby potatoes', '1 small onion ...            Snack
# ...

# %%
df2 = df.drop_duplicates('RecipeName')

# %%
df2
# Out:
#      Unnamed: 0.2             RecipeName  \
# 0               0                Hù Tiéu
# 2               2               Donzelle
# 3               3           Albaloo Polo
# 4               4  Batatinha em Conserva
# 5               5     Macarrão Misturado
# ..            ...                    ...
# 133           133                Pastina
# 134           134       Kakadiche Dhirde
# 135           135        Espagueti Verde
# 136           136                Gombotz
# 137           137    Pink Beetroot Pasta
#
#                                            Ingredients           Course  \
# 0    ['dry rice noodles medium size', 'Hù Tiéu soup...        Breakfast
# 2    ['500 g 00 flour', '1 Tbsp sugar', '1 Tbsp sal...            Snack
# 3    ['2 cups Basmati Rice', '2 tbsp Salt', '1/8 ts...           Dinner
# 4    ['1 can cooked baby potatoes', '1 small onion ...            Snack
# 5    ['200 g milk', '1 Tbsp butter', '1 Tbsp flour'...           Dinner
# ...

# %%
df2.to_csv('IndianFoodDataset4.csv')
